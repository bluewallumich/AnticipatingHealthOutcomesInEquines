# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.set_option('display.max_columns', None)

# %%
test_file = 'Input_Data/test.csv'
train_file = 'Input_Data/train.csv'

# %%
test_data = pd.read_csv(test_file)
train_data = pd.read_csv(train_file)

# %%
train_data.head()
# Out:
#    id surgery    age  hospital_number  rectal_temp  pulse  respiratory_rate  \
# 0   0     yes  adult           530001         38.1  132.0              24.0
# 1   1     yes  adult           533836         37.5   88.0              12.0
# 2   2     yes  adult           529812         38.3  120.0              28.0
# 3   3     yes  adult          5262541         37.1   72.0              30.0
# 4   4      no  adult          5299629         38.0   52.0              48.0
#
#   temp_of_extremities peripheral_pulse mucous_membrane capillary_refill_time  \
# 0                cool          reduced   dark_cyanotic            more_3_sec
# 1                cool           normal   pale_cyanotic            more_3_sec
# 2                cool          reduced       pale_pink            less_3_sec
# 3                cold          reduced       pale_pink            more_3_sec
# 4              normal           normal     normal_pink            less_3_sec
#
#            pain peristalsis abdominal_distention nasogastric_tube  \
# 0     depressed      absent               slight           slight
# 1     mild_pain      absent             moderate             none
# 2  extreme_pain  hypomotile             moderate           slight
# 3     mild_pain  hypomotile             moderate           slight
# 4         alert  hypomotile                 none           slight
#
#   nasogastric_reflux  nasogastric_reflux_ph rectal_exam_feces        abdomen  \
# 0       less_1_liter                    6.5         decreased  distend_small
# 1       more_1_liter                    2.0            absent  distend_small
# 2               none                    3.5               NaN  distend_large
# 3       more_1_liter                    2.0         decreased  distend_small
# 4       less_1_liter                    7.0            normal         normal
#
#    packed_cell_volume  total_protein abdomo_appearance  abdomo_protein  \
# 0                57.0            8.5     serosanguious             3.4
# 1                33.0           64.0     serosanguious             2.0
# 2                37.0            6.4     serosanguious             3.4
# 3                53.0            7.0            cloudy             3.9
# 4                47.0            7.3            cloudy             2.6
#
#   surgical_lesion  lesion_1  lesion_2  lesion_3 cp_data     outcome
# 0             yes      2209         0         0      no        died
# 1             yes      2208         0         0      no  euthanized
# 2             yes      5124         0         0      no       lived
# 3             yes      2208         0         0     yes       lived
# 4              no         0         0         0     yes       lived

# %%
#train_data.dtypes

# %%
#test_data.dtypes

# %%
dtypes_df = pd.DataFrame({'train_dtypes':train_data.dtypes,
                         'test_dtypes':test_data.dtypes})
#dtypes_df

# %%
pivot_df = dtypes_df.transpose()
pivot_df
# Out:
#              abdomen abdominal_distention abdomo_appearance abdomo_protein  \
# train_dtypes  object               object            object        float64
# test_dtypes   object               object            object        float64
#
#                  age capillary_refill_time cp_data hospital_number     id  \
# train_dtypes  object                object  object           int64  int64
# test_dtypes   object                object  object           int64  int64
#
#              lesion_1 lesion_2 lesion_3 mucous_membrane nasogastric_reflux  \
# train_dtypes    int64    int64    int64          object             object
# test_dtypes     int64    int64    int64          object             object
#
#              nasogastric_reflux_ph nasogastric_tube outcome  \
# train_dtypes               float64           object  object
# test_dtypes                float64           object     NaN
#
#              packed_cell_volume    pain peripheral_pulse peristalsis    pulse  \
# train_dtypes            float64  object           object      object  float64
# test_dtypes             float64  object           object      object  float64
#
#              rectal_exam_feces rectal_temp respiratory_rate surgery  \
# train_dtypes            object     float64          float64  object
# test_dtypes             object     float64          float64  object
#
#              surgical_lesion temp_of_extremities total_protein
# train_dtypes          object              object       float64
# test_dtypes           object              object       float64

# %%
for column in train_data.columns:
    if train_data[column].dtypes == 'object':
        print(column)
# Out:
# surgery
# age
# temp_of_extremities
# peripheral_pulse
# mucous_membrane
# capillary_refill_time
# pain
# peristalsis
# abdominal_distention
# nasogastric_tube
# nasogastric_reflux
# rectal_exam_feces
# abdomen
# abdomo_appearance
# surgical_lesion
# cp_data
# outcome

# %%
for column in test_data.columns:
    if test_data[column].dtypes == 'object':
        print(column)
# Out:
# surgery
# age
# temp_of_extremities
# peripheral_pulse
# mucous_membrane
# capillary_refill_time
# pain
# peristalsis
# abdominal_distention
# nasogastric_tube
# nasogastric_reflux
# rectal_exam_feces
# abdomen
# abdomo_appearance
# surgical_lesion
# cp_data

# %%
train_values_dict = {column: train_data[column].unique().tolist() for column in train_data.columns if train_data[column].dtypes == 'object'}

# %%
#train_values_dict

# %%
for column in train_data.select_dtypes(include=["object"]):
    train_data[column]=train_data[column].fillna("no_measure_recorded")
    
for column in test_data.select_dtypes(include=["object"]):
    test_data[column]=test_data[column].fillna("no_measure_recorded")

# %%
train_values_dict = {column: train_data[column].unique().tolist() for column in train_data.columns if train_data[column].dtypes == 'object'}
test_values_dict = {column: test_data[column].unique().tolist() for column in test_data.columns if test_data[column].dtypes == 'object'}
test_values_dict
# Out:
# {'surgery': ['no', 'yes'],
#  'age': ['adult', 'young'],
#  'temp_of_extremities': ['normal',
#   'cool',
#   'no_measure_recorded',
#   'cold',
#   'warm'],
#  'peripheral_pulse': ['normal',
#   'reduced',
#   'no_measure_recorded',
#   'absent',
#   'increased'],
#  'mucous_membrane': ['normal_pink',
#   'bright_pink',
#   'bright_red',
#   'pale_cyanotic',
#   'dark_cyanotic',
#   'pale_pink',
#   'no_measure_recorded'],
#  'capillary_refill_time': ['less_3_sec',
#   'more_3_sec',
#   'no_measure_recorded',
#   '3'],
#  'pain': ['mild_pain',
#   'depressed',
#   'severe_pain',
#   'extreme_pain',
#   'no_measure_recorded',
#   'moderate',
#   'alert'],
#  'peristalsis': ['hypomotile',
#   'absent',
#   'hypermotile',
#   'no_measure_recorded',
#   'normal'],
#  'abdominal_distention': ['slight',
#   'moderate',
#   'severe',
#   'none',
#   'no_measure_recorded'],
#  'nasogastric_tube': ['none', 'slight', 'no_measure_recorded', 'significant'],
#  'nasogastric_reflux': ['none',
#   'more_1_liter',
#   'less_1_liter',
#   'no_measure_recorded'],
#  'rectal_exam_feces': ['normal',
#   'decreased',
#   'absent',
#   'no_measure_recorded',
#   'increased'],
#  'abdomen': ['distend_small',
#   'distend_large',
#   'no_measure_recorded',
#   'other',
#   'firm',
#   'normal'],
#  'abdomo_appearance': ['clear',
#   'serosanguious',
#   'cloudy',
#   'no_measure_recorded'],
#  'surgical_lesion': ['no', 'yes'],
#  'cp_data': ['no', 'yes']}

# %%
test_data
# Out:
#        id surgery    age  hospital_number  rectal_temp  pulse  \
# 0    1235      no  adult           534053         38.6   40.0
# 1    1236     yes  adult           528469         38.2  112.0
# 2    1237     yes  adult           528178         37.7   66.0
# 3    1238      no  adult           534784         37.1   88.0
# 4    1239     yes  adult           529840         38.3   50.0
# ..    ...     ...    ...              ...          ...    ...
# 819  2054      no  adult           529461         40.3  114.0
# 820  2055     yes  adult           535338         37.2  100.0
# 821  2056     yes  adult           529640         39.2  132.0
# 822  2057      no  adult          5287179         38.3   54.0
# 823  2058     yes  adult           528461         38.1   66.0
#
#      respiratory_rate  temp_of_extremities peripheral_pulse mucous_membrane  \
# 0                20.0               normal           normal     normal_pink
# 1                48.0                 cool          reduced     bright_pink
# 2                12.0                 cool           normal      bright_red
# 3                20.0                 cool          reduced   pale_cyanotic
# 4                12.0  no_measure_recorded           normal     bright_pink
# ..                ...                  ...              ...             ...
# 819              36.0                 cool          reduced     normal_pink
# 820              20.0                 cool          reduced   pale_cyanotic
# 821              12.0                 cool          reduced   dark_cyanotic
# 822              66.0               normal           normal     normal_pink
# 823              12.0                 cold           normal     normal_pink
#
#     capillary_refill_time          pain peristalsis abdominal_distention  \
# 0              less_3_sec     mild_pain  hypomotile               slight
# 1              more_3_sec     depressed  hypomotile             moderate
# 2              less_3_sec     mild_pain  hypomotile               slight
# 3              less_3_sec     depressed      absent               severe
# 4              less_3_sec     mild_pain      absent               slight
# ..                    ...           ...         ...                  ...
# 819            more_3_sec     depressed  hypomotile             moderate
# 820            more_3_sec  extreme_pain      absent             moderate
# 821            more_3_sec     depressed  hypomotile             moderate
# 822            less_3_sec     mild_pain  hypomotile                 none
# 823            less_3_sec     mild_pain  hypomotile               slight
#
#         nasogastric_tube nasogastric_reflux  nasogastric_reflux_ph  \
# 0                   none               none                    7.0
# 1                 slight               none                    3.5
# 2                 slight               none                    3.0
# 3                 slight       more_1_liter                    2.0
# 4                 slight               none                    3.0
# ..                   ...                ...                    ...
# 819  no_measure_recorded               none                    7.0
# 820               slight       more_1_liter                    2.0
# 821               slight       more_1_liter                    6.5
# 822               slight               none                    7.0
# 823               slight       more_1_liter                    2.0
#
#     rectal_exam_feces              abdomen  packed_cell_volume  total_protein  \
# 0              normal        distend_small                42.0            7.5
# 1           decreased        distend_small                44.0            6.0
# 2              normal        distend_small                31.5            6.0
# 3              absent        distend_large                75.0           81.0
# 4           decreased        distend_small                37.0            6.8
# ..                ...                  ...                 ...            ...
# 819            normal        distend_large                57.0            8.1
# 820            absent        distend_small                50.0           66.0
# 821         decreased  no_measure_recorded                53.0            7.6
# 822            normal  no_measure_recorded                49.0            8.6
# 823            absent        distend_small                31.5            6.2
#
#        abdomo_appearance  abdomo_protein surgical_lesion  lesion_1  lesion_2  \
# 0                  clear             2.3              no         0         0
# 1          serosanguious             2.6              no      2208         0
# 2                 cloudy             1.6             yes      2205         0
# 3    no_measure_recorded             1.0             yes      1400         0
# 4                 cloudy             2.6             yes      2208         0
# ..                   ...             ...             ...       ...       ...
# 819        serosanguious             4.5             yes      3205         0
# 820        serosanguious             2.0             yes      2209         0
# 821        serosanguious             4.5             yes      2205         0
# 822                clear             5.0              no      3111         0
# 823  no_measure_recorded             1.6             yes      2205         0
#
#      lesion_3 cp_data
# 0           0      no
# 1           0     yes
# 2           0     yes
# 3           0      no
# 4           0     yes
# ..        ...     ...
# 819         0     yes
# 820         0      no
# 821         0      no
# 822         0     yes
# 823         0     yes
#
# [824 rows x 28 columns]

# %%
has_zero_id = (train_data['id']==0).any()
has_nan_id = train_data['id'].isnull().any()

has_zero_id
has_nan_id
# Out:
# False

# %%
test_data.sort_values(by='id')
# Out:
#        id surgery    age  hospital_number  rectal_temp  pulse  \
# 0    1235      no  adult           534053         38.6   40.0
# 1    1236     yes  adult           528469         38.2  112.0
# 2    1237     yes  adult           528178         37.7   66.0
# 3    1238      no  adult           534784         37.1   88.0
# 4    1239     yes  adult           529840         38.3   50.0
# ..    ...     ...    ...              ...          ...    ...
# 819  2054      no  adult           529461         40.3  114.0
# 820  2055     yes  adult           535338         37.2  100.0
# 821  2056     yes  adult           529640         39.2  132.0
# 822  2057      no  adult          5287179         38.3   54.0
# 823  2058     yes  adult           528461         38.1   66.0
#
#      respiratory_rate  temp_of_extremities peripheral_pulse mucous_membrane  \
# 0                20.0               normal           normal     normal_pink
# 1                48.0                 cool          reduced     bright_pink
# 2                12.0                 cool           normal      bright_red
# 3                20.0                 cool          reduced   pale_cyanotic
# 4                12.0  no_measure_recorded           normal     bright_pink
# ..                ...                  ...              ...             ...
# 819              36.0                 cool          reduced     normal_pink
# 820              20.0                 cool          reduced   pale_cyanotic
# 821              12.0                 cool          reduced   dark_cyanotic
# 822              66.0               normal           normal     normal_pink
# 823              12.0                 cold           normal     normal_pink
#
#     capillary_refill_time          pain peristalsis abdominal_distention  \
# 0              less_3_sec     mild_pain  hypomotile               slight
# 1              more_3_sec     depressed  hypomotile             moderate
# 2              less_3_sec     mild_pain  hypomotile               slight
# 3              less_3_sec     depressed      absent               severe
# 4              less_3_sec     mild_pain      absent               slight
# ..                    ...           ...         ...                  ...
# 819            more_3_sec     depressed  hypomotile             moderate
# 820            more_3_sec  extreme_pain      absent             moderate
# 821            more_3_sec     depressed  hypomotile             moderate
# 822            less_3_sec     mild_pain  hypomotile                 none
# 823            less_3_sec     mild_pain  hypomotile               slight
#
#         nasogastric_tube nasogastric_reflux  nasogastric_reflux_ph  \
# 0                   none               none                    7.0
# 1                 slight               none                    3.5
# 2                 slight               none                    3.0
# 3                 slight       more_1_liter                    2.0
# 4                 slight               none                    3.0
# ..                   ...                ...                    ...
# 819  no_measure_recorded               none                    7.0
# 820               slight       more_1_liter                    2.0
# 821               slight       more_1_liter                    6.5
# 822               slight               none                    7.0
# 823               slight       more_1_liter                    2.0
#
#     rectal_exam_feces              abdomen  packed_cell_volume  total_protein  \
# 0              normal        distend_small                42.0            7.5
# 1           decreased        distend_small                44.0            6.0
# 2              normal        distend_small                31.5            6.0
# 3              absent        distend_large                75.0           81.0
# 4           decreased        distend_small                37.0            6.8
# ..                ...                  ...                 ...            ...
# 819            normal        distend_large                57.0            8.1
# 820            absent        distend_small                50.0           66.0
# 821         decreased  no_measure_recorded                53.0            7.6
# 822            normal  no_measure_recorded                49.0            8.6
# 823            absent        distend_small                31.5            6.2
#
#        abdomo_appearance  abdomo_protein surgical_lesion  lesion_1  lesion_2  \
# 0                  clear             2.3              no         0         0
# 1          serosanguious             2.6              no      2208         0
# 2                 cloudy             1.6             yes      2205         0
# 3    no_measure_recorded             1.0             yes      1400         0
# 4                 cloudy             2.6             yes      2208         0
# ..                   ...             ...             ...       ...       ...
# 819        serosanguious             4.5             yes      3205         0
# 820        serosanguious             2.0             yes      2209         0
# 821        serosanguious             4.5             yes      2205         0
# 822                clear             5.0              no      3111         0
# 823  no_measure_recorded             1.6             yes      2205         0
#
#      lesion_3 cp_data
# 0           0      no
# 1           0     yes
# 2           0     yes
# 3           0      no
# 4           0     yes
# ..        ...     ...
# 819         0     yes
# 820         0      no
# 821         0      no
# 822         0     yes
# 823         0     yes
#
# [824 rows x 28 columns]

# %%
#!pip install altair
#!pip install vega
import altair as alt

alt.renderers.enable('default')
#alt.renderers.enable('notebook')
alt.data_transformers.enable('json')
#alt.renderers.enable("mimetype")
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('json')

# %%
def assign_binary_label(row):
    if row['surgery'] == 'yes':
        return 1
    else:
        return 0

test_data['binary_label'] = test_data.apply(assign_binary_label, axis=1)

# 2. Filter out rows where age='adult'
adult_data = test_data[test_data['age'] == 'adult']

# 3. Melt the dataframe
object_columns = [col for col in test_data.columns if test_data[col].dtype == 'object']
melted_adult_data = adult_data.melt(id_vars=['binary_label'], value_vars=object_columns)

# 4. Create the Altair chart
# Separate Bar Chart
bar_chart = alt.Chart(melted_adult_data).mark_bar().encode(
    x='binary_label:N',
    y='value:N',
    color=alt.Color('binary_label:N', legend=alt.Legend(title="Surgery Performed"), 
                    scale=alt.Scale(domain=[0, 1], range=["blue", "orange"])),
    tooltip=['variable', 'value']
).properties(width=50)  # Adjusted the width for each facet

# Text Layer
text_chart = bar_chart.mark_text(
    align='center',
    baseline='middle',
    dy=-15
).encode(
    text='count()'
)

# Combine and facet
final_chart = (bar_chart + text_chart).facet(
    column=alt.Column('variable:N', header=alt.Header(labelOrient='right'))
).properties(
    title="Adult Surgery"
)

final_chart
# Out:
# alt.FacetChart(...)

# %%
base = alt.Chart(test_data).mark_bar().encode(
    alt.X("surgery:N", title="Surgery Type"),
    alt.Y("count():Q", title="Count"),
    color="surgery:N"
).properties(title="Distribution of Surgery Types")
base
# Out:
# alt.Chart(...)

# %%
stacked_bar = alt.Chart(test_data).mark_bar().encode(
    alt.X("pain:N"),
    alt.Y("count():Q"),
    color="surgery:N"
).properties(title="Pain Levels based on Surgery Status")
stacked_bar
# Out:
# alt.Chart(...)

# %%
pie = alt.Chart(test_data).mark_arc(innerRadius=50).encode(
    alt.Theta('count():Q'),
    color='pain:N',
    tooltip=['pain:N', 'count():Q']
).properties(width=300, height=300, title="Distribution of Pain Types")
pie
# Out:
# alt.Chart(...)

# %%
heatmap = alt.Chart(test_data).mark_rect().encode(
    alt.X('surgery:N', title='Surgery Status'),
    alt.Y('pain:N', title='Pain Level'),
    alt.Color('count():Q', legend=alt.Legend(title='Count'), scale=alt.Scale(scheme='viridis')),
    tooltip=['surgery:N', 'pain:N', 'count():Q']
).properties(width=400, height=300, title='Heatmap of Pain Level by Surgery Status')

heatmap
# Out:
# alt.Chart(...)

# %%
import altair as alt
import pandas as pd

# Scatter plot colored by surgery
scatter_surgery = alt.Chart(test_data).mark_circle().encode(
    x='respiratory_rate:Q',
    y='rectal_temp:Q',
    color=alt.Color('surgery:N', title='Surgery'),
    tooltip=['respiratory_rate', 'rectal_temp', 'surgery']
).properties(
    width=250,  # Enlarged width
    height=250,  # Enlarged height
    title="Colored by Surgery"
)

# Scatter plot colored by pain
scatter_pain = alt.Chart(test_data).mark_circle().encode(
    x='respiratory_rate:Q',
    y='rectal_temp:Q',
    color=alt.Color('pain:N', title='Pain'),
    tooltip=['respiratory_rate', 'rectal_temp', 'pain']
).properties(
    width=250,  # Enlarged width
    height=250,  # Enlarged height
    title="Colored by Pain"
)

# Scatter plot colored by temp_of_extremities
scatter_temp = alt.Chart(test_data).mark_circle().encode(
    x='respiratory_rate:Q',
    y='rectal_temp:Q',
    color=alt.Color('temp_of_extremities:N', title='Temp of Extremities'),
    tooltip=['respiratory_rate', 'rectal_temp', 'temp_of_extremities']
).properties(
    width=250,  # Enlarged width
    height=250,  # Enlarged height
    title="Colored by Temp of Extremities"
)

# Concatenate the plots horizontally with independent legends
concatenated_plots = (scatter_surgery | scatter_pain | scatter_temp).resolve_legend(color="independent")

concatenated_plots
# Out:
# alt.HConcatChart(...)
